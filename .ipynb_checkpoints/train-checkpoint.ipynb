# %%
# !pip install -r requirements.txt
# Out:
# Collecting aiohappyeyeballs==2.4.3 (from -r requirements.txt (line 1))
#   Using cached aiohappyeyeballs-2.4.3-py3-none-any.whl.metadata (6.1 kB)
# Collecting aiohttp==3.10.10 (from -r requirements.txt (line 2))
#   Using cached aiohttp-3.10.10-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (7.6 kB)
# Requirement already satisfied: aiosignal==1.3.1 in /opt/conda/lib/python3.11/site-packages (from -r requirements.txt (line 3)) (1.3.1)
# Collecting aiostream==0.5.2 (from -r requirements.txt (line 4))
#   Using cached aiostream-0.5.2-py3-none-any.whl.metadata (9.9 kB)
# Requirement already satisfied: annotated-types==0.7.0 in /opt/conda/lib/python3.11/site-packages (from -r requirements.txt (line 5)) (0.7.0)
# Collecting anyio==4.6.2 (from -r requirements.txt (line 6))
#   Using cached anyio-4.6.2-py3-none-any.whl.metadata (4.7 kB)
# Requirement already satisfied: async-timeout==4.0.3 in /opt/conda/lib/python3.11/site-packages (from -r requirements.txt (line 7)) (4.0.3)
# Collecting attrs==24.2.0 (from -r requirements.txt (line 8))
#   Using cached attrs-24.2.0-py3-none-any.whl.metadata (11 kB)
# Collecting certifi==2024.8.30 (from -r requirements.txt (line 9))
#   Using cached certifi-2024.8.30-py3-none-any.whl.metadata (2.2 kB)
# Requirement already satisfied: click==8.1.7 in /opt/conda/lib/python3.11/site-packages (from -r requirements.txt (line 10)) (8.1.7)
# Requirement already satisfied: colorama==0.4.6 in /opt/conda/lib/python3.11/site-packages (from -r requirements.txt (line 11)) (0.4.6)
# Requirement already satisfied: exceptiongroup==1.2.2 in /opt/conda/lib/python3.11/site-packages (from -r requirements.txt (line 12)) (1.2.2)
# Collecting fastapi==0.115.2 (from -r requirements.txt (line 13))
#   Using cached fastapi-0.115.2-py3-none-any.whl.metadata (27 kB)
# Collecting filelock==3.16.1 (from -r requirements.txt (line 14))
#   Using cached filelock-3.16.1-py3-none-any.whl.metadata (2.9 kB)
# Requirement already satisfied: frozenlist==1.4.1 in /opt/conda/lib/python3.11/site-packages (from -r requirements.txt (line 15)) (1.4.1)
# Collecting fsspec==2024.9.0 (from -r requirements.txt (line 16))
#   Using cached fsspec-2024.9.0-py3-none-any.whl.metadata (11 kB)
# Collecting grpclib==0.4.7 (from -r requirements.txt (line 17))
#   Using cached grpclib-0.4.7-py3-none-any.whl
# Requirement already satisfied: h2==4.1.0 in /opt/conda/lib/python3.11/site-packages (from -r requirements.txt (line 18)) (4.1.0)
# Requirement already satisfied: hpack==4.0.0 in /opt/conda/lib/python3.11/site-packages (from -r requirements.txt (line 19)) (4.0.0)
# Requirement already satisfied: hyperframe==6.0.1 in /opt/conda/lib/python3.11/site-packages (from -r requirements.txt (line 20)) (6.0.1)
# Collecting idna==3.10 (from -r requirements.txt (line 21))
#   Using cached idna-3.10-py3-none-any.whl.metadata (10 kB)
# Collecting intel-openmp==2021.4.0 (from -r requirements.txt (line 22))
#   Using cached intel_openmp-2021.4.0-py2.py3-none-manylinux1_x86_64.whl.metadata (1.1 kB)
# Requirement already satisfied: Jinja2==3.1.4 in /opt/conda/lib/python3.11/site-packages (from -r requirements.txt (line 23)) (3.1.4)
# Collecting lightning-utilities==0.11.7 (from -r requirements.txt (line 24))
#   Using cached lightning_utilities-0.11.7-py3-none-any.whl.metadata (5.2 kB)
# Requirement already satisfied: markdown-it-py==3.0.0 in /opt/conda/lib/python3.11/site-packages (from -r requirements.txt (line 25)) (3.0.0)
# Collecting MarkupSafe==3.0.1 (from -r requirements.txt (line 26))
#   Using cached MarkupSafe-3.0.1-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.0 kB)
# Requirement already satisfied: mdurl==0.1.2 in /opt/conda/lib/python3.11/site-packages (from -r requirements.txt (line 27)) (0.1.2)
# Collecting mkl==2021.4.0 (from -r requirements.txt (line 28))
#   Using cached mkl-2021.4.0-py2.py3-none-manylinux1_x86_64.whl.metadata (1.3 kB)
# Collecting modal==0.64.178 (from -r requirements.txt (line 29))
#   Using cached modal-0.64.178-py3-none-any.whl.metadata (2.4 kB)
# Requirement already satisfied: mpmath==1.3.0 in /opt/conda/lib/python3.11/site-packages (from -r requirements.txt (line 30)) (1.3.0)
# Collecting multidict==6.1.0 (from -r requirements.txt (line 31))
#   Using cached multidict-6.1.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (5.0 kB)
# Collecting networkx==3.4.1 (from -r requirements.txt (line 32))
#   Using cached networkx-3.4.1-py3-none-any.whl.metadata (6.3 kB)
# Requirement already satisfied: numpy==1.26.4 in /opt/conda/lib/python3.11/site-packages (from -r requirements.txt (line 33)) (1.26.4)
# Requirement already satisfied: packaging==24.1 in /opt/conda/lib/python3.11/site-packages (from -r requirements.txt (line 34)) (24.1)
# Collecting pandas==2.2.3 (from -r requirements.txt (line 35))
#   Using cached pandas-2.2.3-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (89 kB)
# Collecting propcache==0.2.0 (from -r requirements.txt (line 36))
#   Using cached propcache-0.2.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (7.7 kB)
# Collecting protobuf==4.25.5 (from -r requirements.txt (line 37))
#   Using cached protobuf-4.25.5-cp37-abi3-manylinux2014_x86_64.whl.metadata (541 bytes)
# Collecting pydantic==2.9.2 (from -r requirements.txt (line 38))
#   Using cached pydantic-2.9.2-py3-none-any.whl.metadata (149 kB)
# Collecting pydantic_core==2.23.4 (from -r requirements.txt (line 39))
#   Using cached pydantic_core-2.23.4-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.6 kB)
# Requirement already satisfied: Pygments==2.18.0 in /opt/conda/lib/python3.11/site-packages (from -r requirements.txt (line 40)) (2.18.0)
# Collecting python-dateutil==2.9.0.post0 (from -r requirements.txt (line 41))
#   Using cached python_dateutil-2.9.0.post0-py2.py3-none-any.whl.metadata (8.4 kB)
# Collecting pytorch-lightning==2.4.0 (from -r requirements.txt (line 42))
#   Using cached pytorch_lightning-2.4.0-py3-none-any.whl.metadata (21 kB)
# Collecting pytz==2024.2 (from -r requirements.txt (line 43))
#   Using cached pytz-2024.2-py2.py3-none-any.whl.metadata (22 kB)
# Requirement already satisfied: PyYAML==6.0.2 in /opt/conda/lib/python3.11/site-packages (from -r requirements.txt (line 44)) (6.0.2)
# Collecting rich==13.9.2 (from -r requirements.txt (line 45))
#   Using cached rich-13.9.2-py3-none-any.whl.metadata (18 kB)
# Requirement already satisfied: shellingham==1.5.4 in /opt/conda/lib/python3.11/site-packages (from -r requirements.txt (line 46)) (1.5.4)
# Collecting sigtools==4.0.1 (from -r requirements.txt (line 47))
#   Using cached sigtools-4.0.1-py2.py3-none-any.whl.metadata (2.4 kB)
# Requirement already satisfied: six==1.16.0 in /opt/conda/lib/python3.11/site-packages (from -r requirements.txt (line 48)) (1.16.0)
# Requirement already satisfied: sniffio==1.3.1 in /opt/conda/lib/python3.11/site-packages (from -r requirements.txt (line 49)) (1.3.1)
# Collecting starlette==0.39.2 (from -r requirements.txt (line 50))
#   Using cached starlette-0.39.2-py3-none-any.whl.metadata (6.0 kB)
# Collecting sympy==1.13.3 (from -r requirements.txt (line 51))
#   Using cached sympy-1.13.3-py3-none-any.whl.metadata (12 kB)
# Collecting synchronicity==0.8.2 (from -r requirements.txt (line 52))
#   Using cached synchronicity-0.8.2-py3-none-any.whl.metadata (8.3 kB)
# Collecting tbb==2021.13.1 (from -r requirements.txt (line 53))
#   Using cached tbb-2021.13.1-py2.py3-none-manylinux1_x86_64.whl.metadata (1.0 kB)
# Requirement already satisfied: timm in /opt/conda/lib/python3.11/site-packages (from -r requirements.txt (line 54)) (0.9.16)
# Collecting toml==0.10.2 (from -r requirements.txt (line 55))
#   Using cached toml-0.10.2-py2.py3-none-any.whl.metadata (7.1 kB)
# Collecting torch==2.3.1 (from -r requirements.txt (line 56))
#   Using cached torch-2.3.1-cp311-cp311-manylinux1_x86_64.whl.metadata (26 kB)
# Collecting torchmetrics==1.4.3 (from -r requirements.txt (line 57))
#   Using cached torchmetrics-1.4.3-py3-none-any.whl.metadata (19 kB)
# Requirement already satisfied: tqdm==4.66.5 in /opt/conda/lib/python3.11/site-packages (from -r requirements.txt (line 58)) (4.66.5)
# Collecting typer==0.12.5 (from -r requirements.txt (line 59))
#   Using cached typer-0.12.5-py3-none-any.whl.metadata (15 kB)
# Collecting types-certifi==2021.10.8.3 (from -r requirements.txt (line 60))
#   Using cached types_certifi-2021.10.8.3-py3-none-any.whl.metadata (1.4 kB)
# Collecting types-toml==0.10.8.20240310 (from -r requirements.txt (line 61))
#   Using cached types_toml-0.10.8.20240310-py3-none-any.whl.metadata (1.5 kB)
# Requirement already satisfied: typing_extensions==4.12.2 in /opt/conda/lib/python3.11/site-packages (from -r requirements.txt (line 62)) (4.12.2)
# Collecting tzdata==2024.2 (from -r requirements.txt (line 63))
#   Using cached tzdata-2024.2-py2.py3-none-any.whl.metadata (1.4 kB)
# Collecting watchfiles==0.24.0 (from -r requirements.txt (line 64))
#   Using cached watchfiles-0.24.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.9 kB)
# Collecting yarl==1.15.2 (from -r requirements.txt (line 65))
#   Using cached yarl-1.15.2-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (56 kB)
# Collecting einops (from -r requirements.txt (line 66))
#   Using cached einops-0.8.0-py3-none-any.whl.metadata (12 kB)
# Collecting labml_nn (from -r requirements.txt (line 67))
#   Using cached labml_nn-0.4.137-py3-none-any.whl.metadata (9.2 kB)
# Collecting labml_helpers (from -r requirements.txt (line 68))
#   Using cached labml_helpers-0.4.89-py3-none-any.whl.metadata (1.4 kB)
# Requirement already satisfied: setuptools in /opt/conda/lib/python3.11/site-packages (from lightning-utilities==0.11.7->-r requirements.txt (line 24)) (72.1.0)
# Collecting nvidia-cuda-nvrtc-cu12==12.1.105 (from torch==2.3.1->-r requirements.txt (line 56))
#   Using cached nvidia_cuda_nvrtc_cu12-12.1.105-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-runtime-cu12==12.1.105 (from torch==2.3.1->-r requirements.txt (line 56))
#   Using cached nvidia_cuda_runtime_cu12-12.1.105-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-cupti-cu12==12.1.105 (from torch==2.3.1->-r requirements.txt (line 56))
#   Using cached nvidia_cuda_cupti_cu12-12.1.105-py3-none-manylinux1_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cudnn-cu12==8.9.2.26 (from torch==2.3.1->-r requirements.txt (line 56))
#   Using cached nvidia_cudnn_cu12-8.9.2.26-py3-none-manylinux1_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cublas-cu12==12.1.3.1 (from torch==2.3.1->-r requirements.txt (line 56))
#   Using cached nvidia_cublas_cu12-12.1.3.1-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cufft-cu12==11.0.2.54 (from torch==2.3.1->-r requirements.txt (line 56))
#   Using cached nvidia_cufft_cu12-11.0.2.54-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-curand-cu12==10.3.2.106 (from torch==2.3.1->-r requirements.txt (line 56))
#   Using cached nvidia_curand_cu12-10.3.2.106-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cusolver-cu12==11.4.5.107 (from torch==2.3.1->-r requirements.txt (line 56))
#   Using cached nvidia_cusolver_cu12-11.4.5.107-py3-none-manylinux1_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cusparse-cu12==12.1.0.106 (from torch==2.3.1->-r requirements.txt (line 56))
#   Using cached nvidia_cusparse_cu12-12.1.0.106-py3-none-manylinux1_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-nccl-cu12==2.20.5 (from torch==2.3.1->-r requirements.txt (line 56))
#   Using cached nvidia_nccl_cu12-2.20.5-py3-none-manylinux2014_x86_64.whl.metadata (1.8 kB)
# Collecting nvidia-nvtx-cu12==12.1.105 (from torch==2.3.1->-r requirements.txt (line 56))
#   Using cached nvidia_nvtx_cu12-12.1.105-py3-none-manylinux1_x86_64.whl.metadata (1.7 kB)
# Collecting triton==2.3.1 (from torch==2.3.1->-r requirements.txt (line 56))
#   Using cached triton-2.3.1-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (1.4 kB)
# Collecting nvidia-nvjitlink-cu12 (from nvidia-cusolver-cu12==11.4.5.107->torch==2.3.1->-r requirements.txt (line 56))
#   Using cached nvidia_nvjitlink_cu12-12.6.77-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Requirement already satisfied: torchvision in /opt/conda/lib/python3.11/site-packages (from timm->-r requirements.txt (line 54)) (0.18.1a0+405940f)
# Requirement already satisfied: huggingface_hub in /opt/conda/lib/python3.11/site-packages (from timm->-r requirements.txt (line 54)) (0.24.5)
# Requirement already satisfied: safetensors in /opt/conda/lib/python3.11/site-packages (from timm->-r requirements.txt (line 54)) (0.4.4)
# Collecting labml==0.4.168 (from labml_nn->-r requirements.txt (line 67))
#   Using cached labml-0.4.168-py3-none-any.whl.metadata (7.5 kB)
# Collecting torchtext (from labml_nn->-r requirements.txt (line 67))
#   Using cached torchtext-0.18.0-cp311-cp311-manylinux1_x86_64.whl.metadata (7.9 kB)
# Collecting fairscale (from labml_nn->-r requirements.txt (line 67))
#   Using cached fairscale-0.4.13-py3-none-any.whl
# Requirement already satisfied: gitpython in /opt/conda/lib/python3.11/site-packages (from labml==0.4.168->labml_nn->-r requirements.txt (line 67)) (3.1.43)
# Requirement already satisfied: requests in /opt/conda/lib/python3.11/site-packages (from huggingface_hub->timm->-r requirements.txt (line 54)) (2.32.3)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /opt/conda/lib/python3.11/site-packages (from torchvision->timm->-r requirements.txt (line 54)) (10.4.0)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /opt/conda/lib/python3.11/site-packages (from gitpython->labml==0.4.168->labml_nn->-r requirements.txt (line 67)) (4.0.11)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/lib/python3.11/site-packages (from requests->huggingface_hub->timm->-r requirements.txt (line 54)) (3.3.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/lib/python3.11/site-packages (from requests->huggingface_hub->timm->-r requirements.txt (line 54)) (1.26.19)
# Requirement already satisfied: smmap<6,>=3.0.1 in /opt/conda/lib/python3.11/site-packages (from gitdb<5,>=4.0.1->gitpython->labml==0.4.168->labml_nn->-r requirements.txt (line 67)) (5.0.0)
# WARNING: The candidate selected for download or install is a yanked version: 'anyio' candidate (version 4.6.2 at https://files.pythonhosted.org/packages/3e/dc/a27d58194ddcbeb295500cc6bf233d4dfb34a95a10ca5dbe4ff8454399e4/anyio-4.6.2-py3-none-any.whl (from https://pypi.org/simple/anyio/) (requires-python:>=3.8))
# Reason for being yanked: This was 4.5.2 code, mistagged
# Using cached aiohappyeyeballs-2.4.3-py3-none-any.whl (14 kB)
# Using cached aiohttp-3.10.10-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.3 MB)
# Using cached aiostream-0.5.2-py3-none-any.whl (39 kB)
# Using cached anyio-4.6.2-py3-none-any.whl (89 kB)
# Using cached attrs-24.2.0-py3-none-any.whl (63 kB)
# Using cached certifi-2024.8.30-py3-none-any.whl (167 kB)
# Using cached fastapi-0.115.2-py3-none-any.whl (94 kB)
# Using cached filelock-3.16.1-py3-none-any.whl (16 kB)
# Using cached fsspec-2024.9.0-py3-none-any.whl (179 kB)
# Using cached idna-3.10-py3-none-any.whl (70 kB)
# Using cached intel_openmp-2021.4.0-py2.py3-none-manylinux1_x86_64.whl (9.9 MB)
# Using cached lightning_utilities-0.11.7-py3-none-any.whl (26 kB)
# Using cached MarkupSafe-3.0.1-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (23 kB)
# Using cached mkl-2021.4.0-py2.py3-none-manylinux1_x86_64.whl (280.9 MB)
# Using cached modal-0.64.178-py3-none-any.whl (552 kB)
# Using cached multidict-6.1.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (129 kB)
# Using cached networkx-3.4.1-py3-none-any.whl (1.7 MB)
# Using cached pandas-2.2.3-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (13.1 MB)
# Using cached propcache-0.2.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (236 kB)
# Using cached protobuf-4.25.5-cp37-abi3-manylinux2014_x86_64.whl (294 kB)
# Using cached pydantic-2.9.2-py3-none-any.whl (434 kB)
# Using cached pydantic_core-2.23.4-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.1 MB)
# Using cached python_dateutil-2.9.0.post0-py2.py3-none-any.whl (229 kB)
# Using cached pytorch_lightning-2.4.0-py3-none-any.whl (815 kB)
# Using cached pytz-2024.2-py2.py3-none-any.whl (508 kB)
# Using cached rich-13.9.2-py3-none-any.whl (242 kB)
# Using cached sigtools-4.0.1-py2.py3-none-any.whl (76 kB)
# Using cached starlette-0.39.2-py3-none-any.whl (73 kB)
# Using cached sympy-1.13.3-py3-none-any.whl (6.2 MB)
# Using cached synchronicity-0.8.2-py3-none-any.whl (31 kB)
# Using cached tbb-2021.13.1-py2.py3-none-manylinux1_x86_64.whl (5.4 MB)
# Using cached toml-0.10.2-py2.py3-none-any.whl (16 kB)
# Using cached torch-2.3.1-cp311-cp311-manylinux1_x86_64.whl (779.2 MB)
# Using cached torchmetrics-1.4.3-py3-none-any.whl (869 kB)
# Using cached typer-0.12.5-py3-none-any.whl (47 kB)
# Using cached types_certifi-2021.10.8.3-py3-none-any.whl (2.1 kB)
# Using cached types_toml-0.10.8.20240310-py3-none-any.whl (4.8 kB)
# Using cached tzdata-2024.2-py2.py3-none-any.whl (346 kB)
# Using cached watchfiles-0.24.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (425 kB)
# Using cached yarl-1.15.2-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (337 kB)
# Using cached nvidia_cublas_cu12-12.1.3.1-py3-none-manylinux1_x86_64.whl (410.6 MB)
# Using cached nvidia_cuda_cupti_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (14.1 MB)
# Using cached nvidia_cuda_nvrtc_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (23.7 MB)
# Using cached nvidia_cuda_runtime_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (823 kB)
# Using cached nvidia_cudnn_cu12-8.9.2.26-py3-none-manylinux1_x86_64.whl (731.7 MB)
# Using cached nvidia_cufft_cu12-11.0.2.54-py3-none-manylinux1_x86_64.whl (121.6 MB)
# Using cached nvidia_curand_cu12-10.3.2.106-py3-none-manylinux1_x86_64.whl (56.5 MB)
# Using cached nvidia_cusolver_cu12-11.4.5.107-py3-none-manylinux1_x86_64.whl (124.2 MB)
# Using cached nvidia_cusparse_cu12-12.1.0.106-py3-none-manylinux1_x86_64.whl (196.0 MB)
# Using cached nvidia_nccl_cu12-2.20.5-py3-none-manylinux2014_x86_64.whl (176.2 MB)
# Using cached nvidia_nvtx_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (99 kB)
# Using cached triton-2.3.1-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (168.1 MB)
# Using cached einops-0.8.0-py3-none-any.whl (43 kB)
# Using cached labml_nn-0.4.137-py3-none-any.whl (443 kB)
# Using cached labml_helpers-0.4.89-py3-none-any.whl (24 kB)
# Using cached labml-0.4.168-py3-none-any.whl (130 kB)
# Using cached torchtext-0.18.0-cp311-cp311-manylinux1_x86_64.whl (2.0 MB)
# Using cached nvidia_nvjitlink_cu12-12.6.77-py3-none-manylinux2014_x86_64.whl (19.7 MB)
# Installing collected packages: types-certifi, tbb, pytz, intel-openmp, tzdata, types-toml, toml, sympy, python-dateutil, pydantic_core, protobuf, propcache, nvidia-nvtx-cu12, nvidia-nvjitlink-cu12, nvidia-nccl-cu12, nvidia-curand-cu12, nvidia-cufft-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, networkx, multidict, mkl, MarkupSafe, lightning-utilities, idna, fsspec, filelock, einops, certifi, attrs, aiostream, aiohappyeyeballs, yarl, triton, sigtools, rich, pydantic, pandas, nvidia-cusparse-cu12, nvidia-cudnn-cu12, grpclib, anyio, watchfiles, typer, synchronicity, starlette, nvidia-cusolver-cu12, labml, aiohttp, torch, fastapi, torchtext, torchmetrics, modal, labml_helpers, fairscale, pytorch-lightning, labml_nn
#   Attempting uninstall: pytz
#     Found existing installation: pytz 2023.3
#     Uninstalling pytz-2023.3:
#       Successfully uninstalled pytz-2023.3
#   Attempting uninstall: tzdata
#     Found existing installation: tzdata 2024.1
#     Uninstalling tzdata-2024.1:
#       Successfully uninstalled tzdata-2024.1
#   Attempting uninstall: sympy
#     Found existing installation: sympy 1.13.2
#     Uninstalling sympy-1.13.2:
#       Successfully uninstalled sympy-1.13.2
#   Attempting uninstall: python-dateutil
#     Found existing installation: python-dateutil 2.9.0
#     Uninstalling python-dateutil-2.9.0:
#       Successfully uninstalled python-dateutil-2.9.0
#   Attempting uninstall: pydantic_core
#     Found existing installation: pydantic_core 2.18.4
#     Uninstalling pydantic_core-2.18.4:
#       Successfully uninstalled pydantic_core-2.18.4
#   Attempting uninstall: protobuf
#     Found existing installation: protobuf 4.25.3
#     Uninstalling protobuf-4.25.3:
#       Successfully uninstalled protobuf-4.25.3
#   Attempting uninstall: networkx
#     Found existing installation: networkx 3.3
#     Uninstalling networkx-3.3:
#       Successfully uninstalled networkx-3.3
#   Attempting uninstall: multidict
#     Found existing installation: multidict 6.0.5
#     Uninstalling multidict-6.0.5:
#       Successfully uninstalled multidict-6.0.5
#   Attempting uninstall: MarkupSafe
#     Found existing installation: MarkupSafe 2.1.5
#     Uninstalling MarkupSafe-2.1.5:
#       Successfully uninstalled MarkupSafe-2.1.5
#   Attempting uninstall: lightning-utilities
#     Found existing installation: lightning-utilities 0.11.6
#     Uninstalling lightning-utilities-0.11.6:
#       Successfully uninstalled lightning-utilities-0.11.6
#   Attempting uninstall: idna
#     Found existing installation: idna 3.7
#     Uninstalling idna-3.7:
#       Successfully uninstalled idna-3.7
#   Attempting uninstall: fsspec
#     Found existing installation: fsspec 2023.6.0
#     Uninstalling fsspec-2023.6.0:
#       Successfully uninstalled fsspec-2023.6.0
#   Attempting uninstall: filelock
#     Found existing installation: filelock 3.15.4
#     Uninstalling filelock-3.15.4:
#       Successfully uninstalled filelock-3.15.4
#   Attempting uninstall: certifi
#     Found existing installation: certifi 2024.7.4
#     Uninstalling certifi-2024.7.4:
#       Successfully uninstalled certifi-2024.7.4
#   Attempting uninstall: attrs
#     Found existing installation: attrs 23.2.0
#     Uninstalling attrs-23.2.0:
#       Successfully uninstalled attrs-23.2.0
#   Attempting uninstall: yarl
#     Found existing installation: yarl 1.9.4
#     Uninstalling yarl-1.9.4:
#       Successfully uninstalled yarl-1.9.4
#   Attempting uninstall: rich
#     Found existing installation: rich 13.7.1
#     Uninstalling rich-13.7.1:
#       Successfully uninstalled rich-13.7.1
#   Attempting uninstall: pydantic
#     Found existing installation: pydantic 1.10.17
#     Uninstalling pydantic-1.10.17:
#       Successfully uninstalled pydantic-1.10.17
#   Attempting uninstall: pandas
#     Found existing installation: pandas 2.2.2
#     Uninstalling pandas-2.2.2:
#       Successfully uninstalled pandas-2.2.2
#   Attempting uninstall: anyio
#     Found existing installation: anyio 4.4.0
#     Uninstalling anyio-4.4.0:
#       Successfully uninstalled anyio-4.4.0
#   Attempting uninstall: typer
#     Found existing installation: typer 0.9.4
#     Uninstalling typer-0.9.4:
#       Successfully uninstalled typer-0.9.4
#   Attempting uninstall: starlette
#     Found existing installation: starlette 0.37.2
#     Uninstalling starlette-0.37.2:
#       Successfully uninstalled starlette-0.37.2
#   Attempting uninstall: aiohttp
#     Found existing installation: aiohttp 3.9.5
#     Uninstalling aiohttp-3.9.5:
#       Successfully uninstalled aiohttp-3.9.5
#   Attempting uninstall: torch
#     Found existing installation: torch 2.3.1.post300
#     Uninstalling torch-2.3.1.post300:
#       Successfully uninstalled torch-2.3.1.post300
#   Attempting uninstall: fastapi
#     Found existing installation: fastapi 0.110.3
#     Uninstalling fastapi-0.110.3:
#       Successfully uninstalled fastapi-0.110.3
#   Attempting uninstall: torchmetrics
#     Found existing installation: torchmetrics 1.2.1
#     Uninstalling torchmetrics-1.2.1:
#       Successfully uninstalled torchmetrics-1.2.1
#   Attempting uninstall: pytorch-lightning
#     Found existing installation: pytorch-lightning 2.3.3
#     Uninstalling pytorch-lightning-2.3.3:
#       Successfully uninstalled pytorch-lightning-2.3.3
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# autogluon-multimodal 1.1.1 requires nvidia-ml-py3==7.352.0, which is not installed.
# jupyter-ai 2.20.0 requires faiss-cpu<=1.8.0, which is not installed.
# amazon-sagemaker-sql-magic 0.1.3 requires sqlparse==0.5.0, but you have sqlparse 0.5.1 which is incompatible.
# autogluon-core 1.1.1 requires scikit-learn<1.4.1,>=1.3.0, but you have scikit-learn 1.4.2 which is incompatible.
# autogluon-features 1.1.1 requires scikit-learn<1.4.1,>=1.3.0, but you have scikit-learn 1.4.2 which is incompatible.
# autogluon-multimodal 1.1.1 requires omegaconf<2.3.0,>=2.1.1, but you have omegaconf 2.3.0 which is incompatible.
# autogluon-multimodal 1.1.1 requires scikit-learn<1.4.1,>=1.3.0, but you have scikit-learn 1.4.2 which is incompatible.
# autogluon-multimodal 1.1.1 requires torchmetrics<1.3.0,>=1.2.0, but you have torchmetrics 1.4.3 which is incompatible.
# autogluon-tabular 1.1.1 requires scikit-learn<1.4.1,>=1.3.0, but you have scikit-learn 1.4.2 which is incompatible.
# autogluon-timeseries 1.1.1 requires gluonts==0.15.1, but you have gluonts 0.14.3 which is incompatible.
# autogluon-timeseries 1.1.1 requires pytorch-lightning<2.4,>=2.2, but you have pytorch-lightning 2.4.0 which is incompatible.
# autovizwidget 0.21.0 requires pandas<2.0.0,>=0.20.1, but you have pandas 2.2.3 which is incompatible.
# datasets 2.21.0 requires fsspec[http]<=2024.6.1,>=2023.1.0, but you have fsspec 2024.9.0 which is incompatible.
# hdijupyterutils 0.21.0 requires pandas<2.0.0,>=0.17.1, but you have pandas 2.2.3 which is incompatible.
# jupyter-scheduler 2.7.1 requires fsspec==2023.6.0, but you have fsspec 2024.9.0 which is incompatible.
# jupyter-scheduler 2.7.1 requires pytz==2023.3, but you have pytz 2024.2 which is incompatible.
# langchain-community 0.2.12 requires langchain<0.3.0,>=0.2.13, but you have langchain 0.2.5 which is incompatible.
# sagemaker 2.227.0 requires attrs<24,>=23.1.0, but you have attrs 24.2.0 which is incompatible.
# sagemaker 2.227.0 requires boto3<2.0,>=1.34.142, but you have boto3 1.34.131 which is incompatible.
# sparkmagic 0.21.0 requires pandas<2.0.0,>=0.17.1, but you have pandas 2.2.3 which is incompatible.
# Successfully installed MarkupSafe-3.0.1 aiohappyeyeballs-2.4.3 aiohttp-3.10.10 aiostream-0.5.2 anyio-4.6.2 attrs-24.2.0 certifi-2024.8.30 einops-0.8.0 fairscale-0.4.13 fastapi-0.115.2 filelock-3.16.1 fsspec-2023.6.0 grpclib-0.4.7 idna-3.10 intel-openmp-2021.4.0 labml-0.4.168 labml_helpers-0.4.89 labml_nn-0.4.137 lightning-utilities-0.11.7 mkl-2021.4.0 modal-0.64.178 multidict-6.1.0 networkx-3.4.1 nvidia-cublas-cu12-12.1.3.1 nvidia-cuda-cupti-cu12-12.1.105 nvidia-cuda-nvrtc-cu12-12.1.105 nvidia-cuda-runtime-cu12-12.1.105 nvidia-cudnn-cu12-8.9.2.26 nvidia-cufft-cu12-11.0.2.54 nvidia-curand-cu12-10.3.2.106 nvidia-cusolver-cu12-11.4.5.107 nvidia-cusparse-cu12-12.1.0.106 nvidia-nccl-cu12-2.20.5 nvidia-nvjitlink-cu12-12.6.77 nvidia-nvtx-cu12-12.1.105 pandas-2.2.3 propcache-0.2.0 protobuf-4.25.5 pydantic-2.7.3 pydantic_core-2.23.4 python-dateutil-2.9.0.post0 pytorch-lightning-2.4.0 pytz-2023.3 rich-13.9.2 sigtools-4.0.1 starlette-0.39.2 sympy-1.13.3 synchronicity-0.8.2 tbb-2021.13.1 toml-0.10.2 torch-2.3.1 torchmetrics-1.4.3 torchtext-0.18.0 triton-2.3.1 typer-0.12.5 types-certifi-2021.10.8.3 types-toml-0.10.8.20240310 tzdata-2024.2 watchfiles-0.24.0 yarl-1.15.2

# %%
import boto3
import os 

s3_resource = boto3.resource('s3')
bucket = s3_resource.Bucket('sgn-sagemaker-dev') 
os.makedirs("data",exist_ok=True)
for obj in bucket.objects.filter(Prefix = 'patient_retention/data'):
    if "." in os.path.basename(obj.key):
        if(not os.path.exists(os.path.basename(obj.key))):
            bucket.download_file(obj.key, os.path.join('data',os.path.basename(obj.key)))
print("test")
# Out:
# test

# %%
import pytorch_lightning as pl
from pytorch_lightning.callbacks import ModelCheckpoint,EarlyStopping
from pytorch_lightning.loggers import CSVLogger
import torch

from data_module import PatientDataModule
from model_module import PatientModelModule 

from train_util.utils import load_hparams_from_yaml

model_name = 'lstm'
cur_date = datetime.now().isoformat()

hparams_path = f"configs/{model_name}.yaml"
hparams = load_hparams_from_yaml(hparams_path)
datamodule = PatientDataModule(hparams_path)
model = PatientModelModule(hparams_path)

# %%
checkpoint_cb = ModelCheckpoint(
    dirpath=f"log/{model_name}-{}/checkpoints",
    filename=f'{hparams["model"]["name"]}' + "_epoch({epoch:02d})_step({step:04d})_val_{val/mse:.4f}",
    
    monitor="val/mse",
    mode="min",
    
    auto_insert_metric_name=False,
    
    save_last=True,
    save_weights_only=True,
    save_top_k=3,
)
csv_logger = CSVLogger(
    save_dir="/saved/logs"
)
early_stopping_cb = EarlyStopping(
    monitor="val/mse",
    mode="min",
    patience=5,
    min_delta = 0
)

# input_temp = torch.randn((4,16,49))
# output = model.net(input_temp)
# print(output.shape)

trainer = pl.Trainer(
    accelerator="gpu",
    devices=[0],
    logger=csv_logger,
    precision=32,
    max_epochs=hparams["training_param"]["max_epochs"],
    check_val_every_n_epoch=1,
    callbacks=[
        checkpoint_cb,
        early_stopping_cb
    ],
    log_every_n_steps=5
)
# Out:
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# HPU available: False, using: 0 HPUs

# %%
trainer.fit(model=model,datamodule=datamodule)
trainer.test(model=model,datamodule=datamodule,ckpt_path="last")
trainer.test(model=model,datamodule=datamodule,ckpt_path="best")
# Out:
# Missing logger folder: /root/saved/logs/lightning_logs
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 trainer.fit(model=model,datamodule=datamodule)
#       2 trainer.test(model=model,datamodule=datamodule,ckpt_path="last")
#       3 trainer.test(model=model,datamodule=datamodule,ckpt_path="best")
#
# File /opt/conda/lib/python3.11/site-packages/pytorch_lightning/trainer/trainer.py:543, in fit(self, model, train_dataloaders, val_dataloaders, datamodule, ckpt_path)
#     537     self.training = True
#     538     call._call_and_handle_interrupt(
#     539         self, self._fit_impl, model, train_dataloaders, val_dataloaders, datamodule, ckpt_path
#     540     )
#     542 def _fit_impl(
# --> 543     self,
#     544     model: "pl.LightningModule",
#     545     train_dataloaders: Optional[Union[TRAIN_DATALOADERS, LightningDataModule]] = None,
#     546     val_dataloaders: Optional[EVAL_DATALOADERS] = None,
#     547     datamodule: Optional[LightningDataModule] = None,
#     548     ckpt_path: Optional[_PATH] = None,
#     549 ) -> None:
#     550     log.debug(f"{self.__class__.__name__}: trainer fit stage")
#     552     # if a datamodule comes in as the second arg, then fix it for the user
#
# File /opt/conda/lib/python3.11/site-packages/pytorch_lightning/trainer/call.py:44, in _call_and_handle_interrupt(trainer, trainer_fn, *args, **kwargs)
#      34 def _call_and_handle_interrupt(trainer: "pl.Trainer", trainer_fn: Callable, *args: Any, **kwargs: Any) -> Any:
#      35     r"""Error handling, intended to be used only for main trainer function entry points (fit, validate, test, predict)
#      36     as all errors should funnel through them.
#      37
#    (...)
#      42
#      43     """
# ---> 44     try:
#      45         if trainer.strategy.launcher is not None:
#      46             return trainer.strategy.launcher.launch(trainer_fn, *args, trainer=trainer, **kwargs)
#
# File /opt/conda/lib/python3.11/site-packages/pytorch_lightning/trainer/trainer.py:579, in _fit_impl(self, model, train_dataloaders, val_dataloaders, datamodule, ckpt_path)
#       0 <Error retrieving source code with stack_data see ipython/ipython#13598>
#
# File /opt/conda/lib/python3.11/site-packages/pytorch_lightning/trainer/trainer.py:948, in _run(self, model, ckpt_path)
#     945 call._call_configure_model(self)
#     947 # check if we should delay restoring checkpoint till later
# --> 948 if not self.strategy.restore_checkpoint_after_setup:
#     949     log.debug(f"{self.__class__.__name__}: restoring module and callbacks from checkpoint path: {ckpt_path}")
#     950     self._checkpoint_connector._restore_modules_and_callbacks(ckpt_path)
#
# File /opt/conda/lib/python3.11/site-packages/pytorch_lightning/trainer/call.py:88, in _call_setup_hook(trainer)
#      85 assert trainer.state.fn is not None
#      86 fn = trainer.state.fn
# ---> 88 # It is too early to move the model to the device, but we fake the `LightningModule.device` property
#      89 # so the user can access it in the `LightningModule.setup` hook
#      90 for module in trainer.lightning_module.modules():
#      91     if isinstance(module, _DeviceDtypeModuleMixin):
#
# File /opt/conda/lib/python3.11/site-packages/lightning_fabric/loggers/logger.py:118, in rank_zero_experiment.<locals>.experiment(self)
#     116 if rank_zero_only.rank > 0:
#     117     return _DummyExperiment()
# --> 118 return fn(self)
#
# File /opt/conda/lib/python3.11/site-packages/pytorch_lightning/loggers/csv_logs.py:169, in experiment(self)
#       0 <Error retrieving source code with stack_data see ipython/ipython#13598>
#
# File /opt/conda/lib/python3.11/site-packages/fsspec/implementations/local.py:54, in makedirs(self, path, exist_ok)
#      51     path = self._strip_protocol(path)
#      52     os.makedirs(path, exist_ok=exist_ok)
# ---> 54 def rmdir(self, path):
#      55     path = self._strip_protocol(path)
#      56     os.rmdir(path)
#
# File <frozen os>:215, in makedirs(name, mode, exist_ok)
#
# File <frozen os>:215, in makedirs(name, mode, exist_ok)
#
# File <frozen os>:225, in makedirs(name, mode, exist_ok)
#
# PermissionError: [Errno 13] Permission denied: '/root/saved'
